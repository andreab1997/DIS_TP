# %%
import Integration as Int
import Initialize as Ini
import lhapdf
import numpy as np
import matplotlib.pyplot as plt
import MassiveCoeffFunc as mcf
import TildeCoeffFunc as tcf
import scipy.integrate as integrate
from mpl_toolkits import mplot3d
# %matplotlib widget

# %%
Int.Initialize_all()

# %%
eps = 0.5
mine = lhapdf.mkPDF("MyPDF_mub=mb_nlo")
thre = [mine.quarkMass(5)*ratio for ratio in [0.5,1.,2.0]]
Qlogmin = np.log10(1.)
Qlogmax = np.log10(150.)
Qlog = np.linspace(Qlogmin,Qlogmax,200)
Qcommon = pow(10,Qlog)
Qsing = [np.linspace(thr-eps,thr+eps,5) for thr in thre]
Q = np.sort(np.concatenate((Qcommon,Qsing[0],Qsing[1],Qsing[2])))
# Out:
# LHAPDF 6.4.0 loading /Users/andrea/n3pdf/lhapdf/share/LHAPDF/MyPDF_mub=mb_nlo/MyPDF_mub=mb_nlo_0000.dat
# MyPDF_mub=mb_nlo PDF set, member #0, version 1

# %%
res = [mcf.Cg_2_m_reg(0.1,q,[mine.quarkMass(5)]) for q in Q]

# %%
Q_arr = np.linspace(2,75,130)
Z_arr = np.geomspace(0.8,1,130)
Q,Z = np.meshgrid(Q_arr, Z_arr)
ax = plt.figure().add_subplot(projection='3d')
C = np.array([[tcf.Cg_2_til_reg(z,q,[mine.quarkMass(5)]) for q in Q_arr] for z in Z_arr])
D = np.array([[tcf.Cg_2_til_reg(z,q,[mine.quarkMass(5)], grids=False) for q in Q_arr] for z in Z_arr])
ax.plot_surface(Q, Z, C, cmap='autumn', cstride=2, rstride=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <module>
#       6 D = np.array([[tcf.Cg_2_til_reg(z,q,[mine.quarkMass(5)], grids=False) for q in Q_arr] for z in Z_arr])
#       7 ax.plot_surface(Q, Z, C, cmap='autumn', cstride=2, rstride=2)
# ----> 8 ax.plot_surface(Q, Z, D, cmap='autumn', cstride=2, rstride=2)
#       9 plt.show()
#
# File ~/n3pdf/venv/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File ~/n3pdf/venv/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py:1581, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1578 had_data = self.has_data()
#    1580 if Z.ndim != 2:
# -> 1581     raise ValueError("Argument Z must be 2-dimensional.")
#    1583 Z = cbook._to_unmasked_float_array(Z)
#    1584 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Z.shape
# Out:
# (130, 130)

# %%
def fakecg2(q, thre):
    if q < thre:
        return 0
    return -1e1*(np.log(q)-1)**2

# %%
ax1 = plt.figure().add_subplot()
resfake = [fakecg2(q,3.2) for q in Q]
ax1.plot(Q,res,Q,resfake)
ax1.set_xscale("log")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <module>
#       1 ax1 = plt.figure().add_subplot()
# ----> 2 resfake = [fakecg2(q,3.2) for q in Q]
#       3 ax1.plot(Q,res,Q,resfake)
#       4 ax1.set_xscale("log")
#
# Input In [7], in <listcomp>(.0)
#       1 ax1 = plt.figure().add_subplot()
# ----> 2 resfake = [fakecg2(q,3.2) for q in Q]
#       3 ax1.plot(Q,res,Q,resfake)
#       4 ax1.set_xscale("log")
#
# Input In [6], in fakecg2(q, thre)
#       1 def fakecg2(q, thre):
# ----> 2     if q < thre:
#       3         return 0
#       4     return -1e1*(np.log(q)-1)**2
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pdf = lhapdf.mkPDF("MyPDF_4F_nnlo")
# Out:
# LHAPDF 6.4.0 loading /Users/andrea/n3pdf/lhapdf/share/LHAPDF/MyPDF_4F_nnlo/MyPDF_4F_nnlo_0000.dat
# MyPDF_4F_nnlo PDF set, member #0, version 1

# %%
ax2 = plt.figure().add_subplot()
result = [integrate.quad(lambda z: mcf.Cg_2_m_reg(z,q,[mine.quarkMass(5)])*pdf.xfxQ2(21,0.1*(1.0/z),q**2),0.1,1.0)[0] for q in Q]
ax2.plot(Q,result)
ax2.set_xscale("log")
plt.show()
# Out:
# /Users/andrea/n3pdf/Project/MassiveCoeffFunc.py:24: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(1-thre)
# /var/folders/25/4w83mpb16zv6m8pxz9w5b1qm0000gn/T/ipykernel_25641/1094724741.py:2: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   result = [integrate.quad(lambda z: mcf.Cg_2_m_reg(z,q,[mine.quarkMass(5)])*pdf.xfxQ2(21,0.1*(1.0/z),q**2),0.1,1.0)[0] for q in Q]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
type(result[0])
